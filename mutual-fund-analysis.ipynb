# %% [markdown]
# <a href="https://www.kaggle.com/code/babe8901/mutual-fund-analysis?scriptVersionId=108638650" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd

# setting data dir
dir = "/kaggle/input/mutualsfundsindia/"

# reading the database
data = pd.read_csv(dir + "mutual_funds_india.csv")
 
# printing the top 10 rows
display(data.head(10))
# Out:
#    id AMC_name                                   Mutual Fund Name category  \
# 0   0    Quant            Quant Small Cap Fund Direct Plan Growth   Equity
# 1   1   Canara         Canara Robeco Small Cap Fund Direct Growth   Equity
# 2   2     PGIM  PGIM India Midcap Opportunities Fund Direct Gr...   Equity
# 3   3     Bank         Bank of India Small Cap Fund Direct Growth   Equity
# 4   4    Quant                       Quant Tax Plan Direct Growth   Equity
# 5   5    Quant            Quant Infrastructure Fund Direct Growth   Equity
# 6   6    Quant                   Quant Mid Cap Fund Direct Growth   Equity
# 7   7    Quant                 Quant Flexi Cap Fund Direct Growth   Equity
# 8   8    Quant                    Quant Active Fund Direct Growth   Equity
# 9   9    Kotak                 Kotak Small Cap Fund Direct Growth   Equity
#
#         risk_type  fund_rating  return_1yr  return_3yr  return_5yr
# 0  Very High Risk          4.0        9.98       54.37       22.73
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Scatter plot with id against one year returns
plt.scatter(data['id'], data['return_1yr'])

# Adding Title to the Plot
plt.title("One Year returns Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Mutual Fund ID')
plt.ylabel('Returns in CAGR')
 
plt.show()


# line plot with id against one year returns
plt.plot(data['id'], data['return_1yr'])

# Adding Title to the Plot
plt.title("One Year returns Line Plot")
 
# Setting the X and Y labels
plt.xlabel('Mutual Fund ID')
plt.ylabel('Returns in CAGR')
 
plt.show()

# %%
# Scatter plot with id against three year returns
plt.scatter(data['id'], data['return_3yr'])
 
# Adding Title to the Plot
plt.title("Three Years returns Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Mutual Fund ID')
plt.ylabel('Returns in CAGR')
 
plt.show()


plt.plot(data['id'], data['return_3yr'])
 
# Adding Title to the Plot
plt.title("Three Years returns Line Plot")
 
# Setting the X and Y labels
plt.xlabel('Mutual Fund ID')
plt.ylabel('Returns in CAGR')
 
plt.show()

# %%
# Scatter plot with id against five year returns
plt.scatter(data['id'], data['return_5yr'])
 
# Adding Title to the Plot
plt.title("Five Years returns Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Mutual Fund ID')
plt.ylabel('Returns in CAGR')
 
plt.show()


plt.plot(data['id'], data['return_5yr'])
 
# Adding Title to the Plot
plt.title("Five Years returns line Plot")
 
# Setting the X and Y labels
plt.xlabel('Mutual Fund ID')
plt.ylabel('Returns in CAGR')
 
plt.show()

# %%
# Scatter plot with id against fund rating
plt.scatter(data['id'], data['fund_rating'])
 
# Adding Title to the Plot
plt.title("Fund Ratings")
 
# Setting the X and Y labels
plt.xlabel('Mutual Fund ID')
plt.ylabel('Rating out of 5')
 
plt.show()

# %%
# Scatter plot with id against category
plt.scatter(data['id'], data['category'])
 
# Adding Title to the Plot
plt.title("Category of Funds Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Mutual Fund ID')
plt.ylabel('Returns in CAGR')
 
plt.show()

# %%
# Scatter plot with id against category
plt.scatter(data['id'], data['AMC_name'])
 
# Adding Title to the Plot
plt.title("Category of Funds Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Mutual Fund ID')
plt.ylabel('Returns in CAGR')
 
plt.show()
